# %%
import altair as alt
from altair import datum
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import HTML, Markdown as md

from src.data.read_dataset import get_processed_dataset
from src.visualization import visualize as viz

prov_df = get_processed_dataset('dpc_province')
prov = prov_df.groupby('provincia').nth(-1).reset_index()

# %%
wide = prov_df.pivot('data', 'provincia','totale_casi_per_1M_pop')
province = ['Belluno', 'Treviso', 'Udine', 'Trieste', 'Pordenone', 'Gorizia', 'Padova', 'Venezia', 'Verona']

# %%
import bar_chart_race as bcr

# %%
HTML(bcr.bar_chart_race(df=wide, n_bars=15))
# Out:
# C:\Users\agostine\anaconda3\envs\coronavirus\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\agostine\anaconda3\envs\coronavirus\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\agostine\anaconda3\envs\coronavirus\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\agostine\anaconda3\envs\coronavirus\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\agostine\anaconda3\envs\coronavirus\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
