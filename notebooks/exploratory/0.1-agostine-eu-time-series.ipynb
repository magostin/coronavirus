# %%
import altair as alt

from src.data.read_dataset import get_processed_dataset
from src.visualization import visualize

# %%
df = get_processed_dataset('CSSE')

# %%
filt = df[(df.Country.isin(['Italy', 'Austria', 'France', 'Spain', 'Germany', 'South Korea', 'Switzerland'])) & (df.Date>'2020-02-20')]
filt.tail(10)
# Out:
#            Date      Country Province  Confirmed  Deaths  Recovered
# 7330 2020-03-04        Spain      NaN        222       2          2
# 7356 2020-03-04  Switzerland      NaN         90       0          3
# 7357 2020-03-04      Austria      NaN         29       0          0
# 7472 2020-03-05  South Korea      NaN       6088      35         41
# 7481 2020-03-05       France      NaN        377       6         12
# 7492 2020-03-05      Germany      NaN        482       0         16
# 7498 2020-03-05        Italy      NaN       3858     148        414
# 7503 2020-03-05        Spain      NaN        259       3          2
# 7529 2020-03-05  Switzerland      NaN        114       1          3
# 7530 2020-03-05      Austria      NaN         41       0          0

# %% [markdown]
# ## Number of confirmed cases in selected European countries and South Korea

# %%
alt.themes.enable('theme_1')
from altair import datum

alt.Chart(df[(df.Country.isin(['Italy', 'Austria', 'France', 'Spain', 'Germany', 'South Korea', 'Switzerland'])) & (df.Date>'2020-02-20')]).mark_line().encode(
    alt.Y('Confirmed', scale=alt.Scale(type='log')),
    x='Date',
    color='Country',
    tooltip=['Country', 'Date', 'Confirmed']
).properties(
    height=600,
    width=600
).transform_filter(
    (datum.Confirmed > 20)
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Number of deaths in the same countries

# %%
alt.themes.enable('theme_1')
from altair import datum

alt.Chart(df[(df.Country.isin(['Italy', 'Austria', 'France', 'Spain', 'Germany', 'South Korea', 'Switzerland'])) & (df.Date>'2020-02-20')]).mark_line().encode(
    alt.Y('Deaths'),
    x='Date',
    color='Country',
    tooltip=['Country', 'Date', 'Deaths']
).properties(
    height=600,
    width=600
).transform_filter(
    (datum.Confirmed > 0)
).interactive()
# Out:
# alt.Chart(...)
